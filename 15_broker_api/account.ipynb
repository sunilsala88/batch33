# %%
api_key='PKCGQ99MC5FQA1P8ZSRE'
secret_key='rkWLI1F2poiTbuERdzozfOLgVV6mrFKTH27Ugvb1'

# %%
!  pip install alpaca-py
# Out:
# Collecting alpaca-py
#   Downloading alpaca_py-0.42.2-py3-none-any.whl.metadata (13 kB)
# Collecting msgpack<2.0.0,>=1.0.3 (from alpaca-py)
#   Using cached msgpack-1.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Requirement already satisfied: pandas>=1.5.3 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from alpaca-py) (2.3.2)
# Collecting pydantic<3.0.0,>=2.0.3 (from alpaca-py)
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from alpaca-py) (2.32.5)
# Collecting sseclient-py<2.0.0,>=1.7.2 (from alpaca-py)
#   Using cached sseclient_py-1.8.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: websockets>=10.4 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from alpaca-py) (15.0.1)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.0.3->alpaca-py)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3.0.0,>=2.0.3->alpaca-py)
#   Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (4.15.0)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.0.3->alpaca-py)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (2025.8.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from pandas>=1.5.3->alpaca-py) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from pandas>=1.5.3->alpaca-py) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from pandas>=1.5.3->alpaca-py) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from pandas>=1.5.3->alpaca-py) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/algo trading 2025/batch33/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->alpaca-py) (1.17.0)
# Downloading alpaca_py-0.42.2-py3-none-any.whl (122 kB)
# Using cached msgpack-1.1.1-cp312-cp312-macosx_11_0_arm64.whl (79 kB)
# Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
# Using cached sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: sseclient-py, typing-inspection, pydantic-core, msgpack, annotated-types, pydantic, alpaca-py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [alpaca-py]/7 [alpaca-py]types]n]
# Successfully installed alpaca-py-0.42.2 annotated-types-0.7.0 msgpack-1.1.1 pydantic-2.11.9 pydantic-core-2.33.2 sseclient-py-1.8.0 typing-inspection-0.4.1

# %%
from alpaca.trading.client import TradingClient

trading_client = TradingClient(api_key, secret_key, paper=True)

account = trading_client.get_account()
account
# Out:
# {   'account_blocked': False,
#     'account_number': 'PA32II6CTZQA',
#     'accrued_fees': '0',
#     'buying_power': '660496.2',
#     'cash': '23702.43',
#     'created_at': datetime.datetime(2024, 8, 24, 9, 13, 29, 133143, tzinfo=TzInfo(UTC)),
#     'crypto_status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '660496.2',
#     'equity': '1098919.5',
#     'id': UUID('28959f70-ced0-4150-a908-c1d2ef1a475a'),
#     'initial_margin': '101015.44',
#     'last_equity': '1100258.94890219645',
#     'last_maintenance_margin': '60609.26',
#     'long_market_value': '1075217.07',
#     'maintenance_margin': '60609.26',
#     'multiplier': '4',
#     'non_marginable_buying_power': '122717.87',
#     'options_approved_level': 3,
#     'options_buying_power': '124717.87',
#     'options_trading_level': 3,
#     'pattern_day_trader': True,
#     'pending_transfer_in': None,
#     'pending_transfer_out': None,
#     'portfolio_value': '1098919.5',
#     'regt_buying_power': '249435.74',
#     'short_market_value': '0',
#     'shorting_enabled': True,
#     'sma': '224587.6',
#     'status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False}

# %%
trading_client.get_all_positions()
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('b0b6dd9d-8b9b-48a9-ba46-b9d54906e415'),
#      'asset_marginable': True,
#      'avg_entry_price': '228.28',
#      'avg_entry_swap_rate': None,
#      'change_today': '0',
#      'cost_basis': '456.56',
#      'current_price': '255.46',
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'lastday_price': '255.46',
#      'market_value': '510.92',
#      'qty': '2',
#      'qty_available': '2',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'AAPL',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '54.36',
#      'unrealized_plpc': '0.1190643069914141',
#      'usd': None},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('64bbff51-59d6-4b3c-9351-13ad85e3c752'),
#      'asset_marginable': False,
#      'avg_entry_price': '97984.267246233',
#      'avg_entry_swap_rate': None,
#      'change_today': '0.0001225406144406',
#      'cost_basis': '781914.452331',
#      'current_price': '109364.9',
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'lastday_price': '109351.5',
#      'market_value': '872731.901672',
#      'qty': '7.979999997',
#      'qty_available': '7.979999997',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'BTCUSD',
#      'unrealized_intraday_pl': '106.932',
#      'unrealized_intraday_plpc': '0.0001225406144866',
#      'unrealized_pl': '90817.449341',
#      'unrealized_plpc': '0.1161475517817327',
#      'usd': None},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('a3ba8ac0-166d-460b-b17a-1f035622dd47'),
#      'asset_marginable': False,
#      'avg_entry_price': '0.325',
#      'avg_entry_swap_rate': None,
#      'change_today': '-0.0100524475524476',
#      'cost_basis': '0.324285',
#      'current_price': '0.2265',
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'lastday_price': '0.2288',
#      'market_value': '0.226002',
#      'qty': '0.9978',
#      'qty_available': '0.9978',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'DOGEUSD',
#      'unrealized_intraday_pl': '-0.002295',
#      'unrealized_intraday_plpc': '-0.0100526945163537',
#      'unrealized_pl': '-0.098283',
#      'unrealized_plpc': '-0.3030759979647532',
#      'usd': None},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('e3047683-637a-4fb2-b71d-805cd6fec95d'),
#      'asset_marginable': True,
#      'avg_entry_price': '289.435',
#      'avg_entry_swap_rate': None,
#      'change_today': '0',
#      'cost_basis': '578.87',
#      'current_price': '316.06',
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'lastday_price': '316.06',
#      'market_value': '632.12',
#      'qty': '2',
#      'qty_available': '2',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'JPM',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '53.25',
#      'unrealized_plpc': '0.0919895658783492',
#      'usd': None},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('4ce9353c-66d1-46c2-898f-fce867ab0247'),
#      'asset_marginable': True,
#      'avg_entry_price': '179.95',
#      'avg_entry_swap_rate': None,
#      'change_today': '0',
#      'cost_basis': '359.9',
#      'current_price': '178.19',
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'lastday_price': '178.19',
#      'market_value': '356.38',
#      'qty': '2',
#      'qty_available': '2',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'NVDA',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '-3.52',
#      'unrealized_plpc': '-0.0097804945818283',
#      'usd': None},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#      'asset_marginable': True,
#      'avg_entry_price': '604',
#      'avg_entry_swap_rate': None,
#      'change_today': '0',
#      'cost_basis': '183012',
#      'current_price': '661.82',
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'lastday_price': '661.82',
#      'market_value': '200531.46',
#      'qty': '303',
#      'qty_available': '303',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'SPY',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '17519.46',
#      'unrealized_plpc': '0.0957284768211921',
#      'usd': None}]

# %%
trading_client.get_orders()
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('8ccae427-5dd0-45b3-b5fe-7ba5e422c766'),
#      'canceled_at': None,
#      'client_order_id': '72e12d14-dc7d-499a-b502-0d5a446e712f',
#      'created_at': datetime.datetime(2025, 9, 28, 11, 53, 57, 937276, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'expires_at': datetime.datetime(2025, 9, 29, 20, 0, tzinfo=TzInfo(UTC)),
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('d612956d-7293-458c-bf00-a5511c8c5e03'),
#      'legs': None,
#      'limit_price': '422',
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.LIMIT: 'limit'>,
#      'position_intent': <PositionIntent.BUY_TO_OPEN: 'buy_to_open'>,
#      'qty': '1',
#      'ratio_qty': None,
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.ACCEPTED: 'accepted'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2025, 9, 28, 11, 53, 57, 937276, tzinfo=TzInfo(UTC)),
#      'symbol': 'TSLA',
#      'time_in_force': <TimeInForce.DAY: 'day'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.LIMIT: 'limit'>,
#      'updated_at': datetime.datetime(2025, 9, 28, 11, 53, 57, 969964, tzinfo=TzInfo(UTC))}]
