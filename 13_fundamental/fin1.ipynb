# %%
import yfinance as yf
data=yf.download("AAPL", period="5d", interval="15m",multi_level_index=False)
data
# Out:
# /var/folders/d_/rsnj8g2n4f362bxt3tz9n95w0000gn/T/ipykernel_96378/1119453906.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data=yf.download("AAPL", period="5d", interval="15m",multi_level_index=False)
# [*********************100%***********************]  1 of 1 completed
#                                 Close        High         Low        Open  \
# Datetime
# 2025-09-15 13:30:00+00:00  235.682495  238.190002  235.660004  237.000000
# 2025-09-15 13:45:00+00:00  235.359894  235.940002  235.029999  235.684998
# 2025-09-15 14:00:00+00:00  235.360001  235.669998  235.054993  235.339996
# 2025-09-15 14:15:00+00:00  236.214996  236.300003  235.253403  235.369995
# 2025-09-15 14:30:00+00:00  236.470001  236.619995  235.660004  236.210007
# ...                               ...         ...         ...         ...
# 2025-09-19 18:45:00+00:00  245.509995  245.910004  245.190994  245.809998
# ...

# %%
t1=yf.Ticker('RELIANCE.NS')
i1=t1.info

# %%
i1.get('beta')
# Out:
# 0.217

# %%
dict_of_beta={}
list_of_stocks=['AAPL','MSFT','GOOGL','AMZN','TSLA','META','NVDA','JPM','V','UNH','HD','PG','MA','DIS','PYPL','BAC','ADBE','CMCSA','NFLX','XOM','KO']
for stock in list_of_stocks:
    t1=yf.Ticker(stock)
    i1=t1.info
    beta=i1.get('beta')
    dict_of_beta[stock]=beta

# %%
l1=list(dict_of_beta.values())
i=l1.index(max(l1))
list_of_stocks[i]
# Out:
# 'NVDA'

# %%
name='RELIANCE.NS'
t1=yf.Ticker(name)

# %% [markdown]
# income

# %%
t1.get_incomestmt()
t1.quarterly_incomestmt
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                         3.913198e+07
# Tax Rate For Calcs                                  2.070480e-01
# Normalized EBITDA                                   5.331000e+09
# Total Unusual Items                                 1.890000e+08
# Total Unusual Items Excluding Goodwill              1.890000e+08
# Net Income From Continuing Operation Net Minori...  3.810000e+09
# Reconciled Depreciation                             2.790000e+08
# Reconciled Cost Of Revenue                          4.439000e+09
# EBITDA                                              5.520000e+09
# EBIT                                                5.241000e+09
# Net Interest Income                                -2.570000e+08
# Interest Expense                                    4.450000e+08
# Interest Income                                     1.880000e+08
# ...

# %% [markdown]
# cashflow

# %%
t1.quarterly_cash_flow
# Out:
#                                                   2025-06-30    2025-03-31  \
# Free Cash Flow                                  3.369000e+09 -5.511000e+09
# Repurchase Of Capital Stock                    -1.020000e+08 -3.700000e+08
# Repayment Of Debt                              -1.031000e+09 -1.599000e+09
# Issuance Of Debt                               -1.160000e+08  5.436000e+09
# Issuance Of Capital Stock                       6.400000e+07  1.590000e+08
# Capital Expenditure                            -4.420000e+08 -3.090000e+08
# End Cash Position                               1.020300e+10  8.417000e+09
# Other Cash Adjustment Outside Changein Cash              NaN -3.970000e+08
# Beginning Cash Position                         8.417000e+09  1.148800e+10
# Effect Of Exchange Rate Changes                 1.690000e+08  1.630000e+08
# Changes In Cash                                 1.220000e+09 -2.837000e+09
# ...

# %% [markdown]
# balance sheet

# %%
t1.balancesheet
# Out:
#                                                     2024-12-31    2023-12-31  \
# Treasury Shares Number                            2.738000e+09  2.732000e+09
# Ordinary Shares Number                            4.302000e+09  4.308000e+09
# Share Issued                                      7.040000e+09  7.040000e+09
# Net Debt                                          3.369400e+10  3.269800e+10
# Total Debt                                        4.452200e+10  4.206400e+10
# ...                                                        ...           ...
# Allowance For Doubtful Accounts Receivable       -5.060000e+08 -5.020000e+08
# Gross Accounts Receivable                         4.075000e+09  3.912000e+09
# Cash Cash Equivalents And Short Term Investments  1.457100e+10  1.366300e+10
# Other Short Term Investments                      3.743000e+09  4.297000e+09
# Cash And Cash Equivalents                         1.082800e+10  9.366000e+09
#
# ...
